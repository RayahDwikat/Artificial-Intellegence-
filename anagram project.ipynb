# %%
import numpy as np

# %%
word = open('word.txt','r')

# %%
word
# Out:
# <_io.TextIOWrapper name='word.txt' mode='r' encoding='cp1252'>

# %%
wordlist = word.readlines()

# %%
wordlist[:10]
# Out:
# ['A\n',
#  'a\n',
#  'aa\n',
#  'aal\n',
#  'aalii\n',
#  'aam\n',
#  'Aani\n',
#  'aardvark\n',
#  'aardwolf\n',
#  'Aaron\n']

# %%
len(wordlist)
# Out:
# 235886

# %%
'Aaron\n'.strip()
# Out:
# 'Aaron'

# %%
'Aaron'.lower()
# Out:
# 'aaron'

# %%
wordclean = [word.strip().lower() for word in wordlist]

# %%
wordclean[:10]
# Out:
# ['a',
#  'a',
#  'aa',
#  'aal',
#  'aalii',
#  'aam',
#  'aani',
#  'aardvark',
#  'aardwolf',
#  'aaron']

# %%
wordunique = list(set(wordclean))

# %%
wordunique
# Out:
# ['hohe',
#  'aridian',
#  'bridgebuilding',
#  'pullback',
#  'path',
#  'ureteropyelonephritis',
#  'chaetites',
#  'underdauber',
#  'engold',
#  'caecocolic',
#  'purulent',
#  'criticship',
#  'singlehanded',
#  'croconic',
#  'leucodermatous',
#  'unmoderateness',
#  'valley',
#  'akan',
#  'fimbrillate',
#  'misbetide',
#  'elaeothesium',
#  'ectobatic',
#  'clerkdom',
#  'halieutic',
#  'brevicipitid',
#  'interfoliaceous',
#  'undevious',
#  'mastery',
#  'tetraamylose',
#  'premethodical',
#  'breards',
#  'muraled',
#  'parasitotropism',
#  'oysterhouse',
#  'slugger',
#  'electrosynthesis',
#  'apandry',
#  'buettneria',
#  'reconfuse',
#  'candlesticked',
#  'harmlessness',
#  'postconsonantal',
#  'evulse',
#  'camorra',
#  'tollhouse',
#  'dissolvable',
#  'overexcitement',
#  'nonvillainous',
#  'chromaphore',
#  'telegraphone',
#  'unenjoyable',
#  'sheepwalker',
#  'unfarrowed',
#  'photospectroscope',
#  'griqua',
#  'decretalist',
#  'digamous',
#  'tritozooid',
#  'cremnophobia',
#  'missing',
#  'renes',
#  'resistful',
#  'stank',
#  'landlordry',
#  'ringleadership',
#  'gnatproof',
#  'nontrunked',
#  'cephalon',
#  'fourther',
#  'geoparallelotropic',
#  'levana',
#  'kalendae',
#  'emotiveness',
#  'missile',
#  'wareman',
#  'freudian',
#  'autostarter',
#  'periureteric',
#  'bellware',
#  'nonborrower',
#  'nondisjunctive',
#  'floralia',
#  'hucksterer',
#  'macrostylous',
#  'respectably',
#  'unmourned',
#  'hyalopterous',
#  'flowerlet',
#  'affeer',
#  'urogram',
#  'impairer',
#  'harveyize',
#  'mandaic',
#  'apina',
#  'evaluate',
#  'sleaved',
#  'photoma',
#  'hohenzollern',
#  'devote',
#  'lablab',
#  'undetached',
#  'countermark',
#  'penacute',
#  'discount',
#  'antievolution',
#  'rhubarby',
#  'delegatee',
#  'quannet',
#  'zonulet',
#  'masterhood',
#  'hulsite',
#  'pellard',
#  'cementatory',
#  'nicking',
#  'outsteam',
#  'ezra',
#  'parbuckle',
#  'spheroidical',
#  'plotinical',
#  'sculper',
#  'amphithect',
#  'facinorous',
#  'flocculate',
#  'undeclaimed',
#  'karyology',
#  'stitchwort',
#  'sticker',
#  'gingerbread',
#  'polianite',
#  'reagent',
#  'seeing',
#  'abrasion',
#  'entad',
#  'ileitis',
#  'acate',
#  'parietofrontal',
#  'agnathic',
#  'autology',
#  'crimean',
#  'foothot',
#  'rillstone',
#  'thiocyanic',
#  'steeplebush',
#  'yellowknife',
#  'homoousianist',
#  'interdictory',
#  'antefix',
#  'spanioli',
#  'indivision',
#  'hypocotyledonous',
#  'cetotolite',
#  'retroserrate',
#  'hemimetabolous',
#  'unpostulated',
#  'garum',
#  'knickknackish',
#  'exhaustedly',
#  'guidecraft',
#  'responder',
#  'highboy',
#  'tendential',
#  'predeterminate',
#  'clathraceous',
#  'womenfolk',
#  'orthotype',
#  'acephal',
#  'bighead',
#  'quayman',
#  'colymbriformes',
#  'hyponychium',
#  'uninventiveness',
#  'supersignificant',
#  'tarnlike',
#  'banksman',
#  'embarrel',
#  'snakeholing',
#  'angekok',
#  'chlorococcus',
#  'damier',
#  'undeservingness',
#  'precontroversial',
#  'anabolism',
#  'acrogenously',
#  'disquisitory',
#  'indemnification',
#  'doob',
#  'quarters',
#  'monarchianist',
#  'interwhistle',
#  'cavalierishness',
#  'meningomyelocele',
#  'heterolobous',
#  'transsubjective',
#  'redecline',
#  'graphiter',
#  'sloshy',
#  'descantist',
#  'kelchin',
#  'disedify',
#  'lixiviation',
#  'tracheotomize',
#  'unmingling',
#  'untruther',
#  'collectedly',
#  'urinousness',
#  'biquartz',
#  'edeagra',
#  'take',
#  'hysterectomy',
#  'fundamentalist',
#  'outburn',
#  'carbonigenous',
#  'outpull',
#  'covertical',
#  'titubate',
#  'trufflesque',
#  'mathematicals',
#  'horouta',
#  'expertness',
#  'antiloimic',
#  'hippomancy',
#  'temporoauricular',
#  'dominionist',
#  'mammary',
#  'randomly',
#  'phenomenalization',
#  'reaccredit',
#  'smokewood',
#  'homometrically',
#  'digressionary',
#  'structure',
#  'grailing',
#  'telephonic',
#  'carambole',
#  'unpolitical',
#  'maniva',
#  'oftentime',
#  'undittoed',
#  'adicity',
#  'toponymical',
#  'beamwork',
#  'taluhet',
#  'chronogrammic',
#  'unrelaxable',
#  'pantheonic',
#  'palisander',
#  'reattraction',
#  'unpublishably',
#  'halimeda',
#  'diwata',
#  'porpitoid',
#  'unaffectedly',
#  'admonitor',
#  'iwaiwa',
#  'pentoxide',
#  'predismissory',
#  'canmaking',
#  'cosmoscope',
#  'embryectomy',
#  'oxyacid',
#  'pulvinaria',
#  'uncinariasis',
#  'ciliated',
#  'exuberantness',
#  'pomatomus',
#  'inoperativeness',
#  'posteternity',
#  'reflectedness',
#  'horsemanship',
#  'parvirostrate',
#  'laodicean',
#  'dinginess',
#  'graspable',
#  'unletterlike',
#  'furry',
#  'arquifoux',
#  'uninnocent',
#  'unpartaken',
#  'judge',
#  'anukabiet',
#  'mammillation',
#  'monitorish',
#  'sexologist',
#  'thermomotive',
#  'weanoc',
#  'everduring',
#  'irrationalism',
#  'fabaceous',
#  'unregal',
#  'autogenic',
#  'paganization',
#  'voluptary',
#  'monochromist',
#  'zymotize',
#  'eyepit',
#  'megalosauroid',
#  'radiferous',
#  'occipitocervical',
#  'desacralization',
#  'secalin',
#  'coresign',
#  'monophyllous',
#  'raglet',
#  'spheroquartic',
#  'extrapolate',
#  'intermitted',
#  'plesiobiotic',
#  'colicolitis',
#  'milieu',
#  'fluorescin',
#  'wolfgang',
#  'lightish',
#  'spicery',
#  'hamfat',
#  'scopula',
#  'blephara',
#  'loathful',
#  'nonreasoner',
#  'bathymeter',
#  'nautic',
#  'leglen',
#  'offensively',
#  'vex',
#  'kasha',
#  'papillomatosis',
#  'qualifiable',
#  'thistlish',
#  'udell',
#  'excavate',
#  'unbounded',
#  'loganin',
#  'fecundator',
#  'hebraicize',
#  'uncommanderlike',
#  'echinostome',
#  'acetylation',
#  'cosegment',
#  'transvaalian',
#  'limberness',
#  'heterotropic',
#  'cincinnus',
#  'misbelieve',
#  'cantorship',
#  'stockbreeder',
#  'porometer',
#  'dislove',
#  'unweariedly',
#  'augen',
#  'dyspathetic',
#  'raiae',
#  'polynoid',
#  'coleorhiza',
#  'martineta',
#  'thyreoideal',
#  'staggerbush',
#  'thegnland',
#  'dibbler',
#  'monopoly',
#  'hypogastrium',
#  'syphilidologist',
#  'agentess',
#  'butene',
#  'nonprohibition',
#  'spontaneity',
#  'undergamekeeper',
#  'nonassimilable',
#  'pinchbelly',
#  'groining',
#  'pentahydrate',
#  'whiba',
#  'jitneur',
#  'pseudogyny',
#  'photomural',
#  'stooded',
#  'matrimonious',
#  'mongrelization',
#  'unbrushed',
#  'unpanegyrized',
#  'felid',
#  'uncharnel',
#  'agamid',
#  'combinator',
#  'omnipotency',
#  'titanomagnetite',
#  'anounou',
#  'anticatalytic',
#  'uncharacter',
#  'hydrophinae',
#  'polyspondyly',
#  'reformatory',
#  'palaeolithy',
#  'unfeline',
#  'amphichromatic',
#  'foxfinger',
#  'dehydrosparteine',
#  'hawknut',
#  'isomerically',
#  'otosis',
#  'jinny',
#  'fay',
#  'prefavorable',
#  'millieme',
#  'somnolize',
#  'ceruleous',
#  'myoatrophy',
#  'gonoblast',
#  'cratemaker',
#  'prerenal',
#  'doughman',
#  'tributarily',
#  'boxwood',
#  'palmatilobed',
#  'panzer',
#  'tepefaction',
#  'climatically',
#  'flaggish',
#  'mesityl',
#  'thermopolypneic',
#  'cowherb',
#  'riverly',
#  'brachyuran',
#  'snaps',
#  'unavouched',
#  'shillety',
#  'italianization',
#  'planirostrate',
#  'tetrabranch',
#  'protorosaur',
#  'besogne',
#  'becollier',
#  'footwear',
#  'depopulative',
#  'circumambulatory',
#  'caranda',
#  'transpontine',
#  'uninterruptibleness',
#  'browband',
#  'vinegar',
#  'uralic',
#  'epistaxis',
#  'saily',
#  'heteralocha',
#  'igara',
#  'dryfoot',
#  'inequivalve',
#  'analysation',
#  'doublehanded',
#  'pendecagon',
#  'unturf',
#  'deambulatory',
#  'orthoepist',
#  'adatom',
#  'cabled',
#  'fivefold',
#  'gasterosteiform',
#  'cometary',
#  'fingerberry',
#  'understuffing',
#  'wheneer',
#  'capriciousness',
#  'legitimize',
#  'dialystelic',
#  'retroclusion',
#  'abbas',
#  'pyramidale',
#  'oedemerid',
#  'pennage',
#  'supercongestion',
#  'quackish',
#  'kiestless',
#  'chucking',
#  'fireburn',
#  'revivalism',
#  'chinkerinchee',
#  'slather',
#  'epipastic',
#  'orthosymmetrical',
#  'curateship',
#  'thrack',
#  'granulous',
#  'sulphamyl',
#  'uncontemned',
#  'kokio',
#  'arecain',
#  'upfollow',
#  'aldermanical',
#  'hermione',
#  'mastochondroma',
#  'germinancy',
#  'tuberculed',
#  'anthradiol',
#  'letty',
#  'goldenhair',
#  'schemer',
#  'sterics',
#  'endungeon',
#  'overemotionality',
#  'stepdame',
#  'hydrophanous',
#  'unclew',
#  'categorial',
#  'portuary',
#  'glaciometer',
#  'ephydrid',
#  'gnathite',
#  'probal',
#  'solatia',
#  'saturnalia',
#  'undisturbable',
#  'calciform',
#  'egret',
#  'creamcup',
#  'progne',
#  'camuning',
#  'buncal',
#  'atroscine',
#  'unplump',
#  'untrumpeted',
#  'angiokinesis',
#  'acridian',
#  'pericarpoidal',
#  'sectist',
#  'summed',
#  'unprefigured',
#  'tetrachloroethylene',
#  'hardheadedness',
#  'nonpersecution',
#  'hundred',
#  'dejerate',
#  'cecrops',
#  'unshowy',
#  'arterin',
#  'overtill',
#  'brahminic',
#  'reimpact',
#  'utriculate',
#  'desilicate',
#  'resoundingly',
#  'accultural',
#  'lemon',
#  'shorling',
#  'anametadromous',
#  'gustation',
#  'breadth',
#  'contection',
#  'fatuitousness',
#  'rupicapra',
#  'septal',
#  'unentangle',
#  'yucky',
#  'clocklike',
#  'phrenitic',
#  'sigillographical',
#  'belonesite',
#  'housekeep',
#  'ragamuffinism',
#  'oxygenize',
#  'trunchman',
#  'unsmart',
#  'fortescue',
#  'eatability',
#  'unhousewifely',
#  'really',
#  'stichomythy',
#  'effectual',
#  'unsnarl',
#  'sonderclass',
#  'georgiana',
#  'zaphrentidae',
#  'sheer',
#  'satyress',
#  'alpinery',
#  'hebeosteotomy',
#  'heteromorphous',
#  'somniferous',
#  'swordfishery',
#  'cunoniaceous',
#  'organogel',
#  'vocability',
#  'unpalliable',
#  'leadwort',
#  'calyptriform',
#  'unspattered',
#  'erased',
#  'greekless',
#  'routivarite',
#  'elytrigerous',
#  'insubstantiate',
#  'pharmacoendocrinology',
#  'undelayedly',
#  'manas',
#  'obsidional',
#  'warming',
#  'arsenohemol',
#  'input',
#  'gonnardite',
#  'laterigradae',
#  'moniliformly',
#  'anhydridization',
#  'grossification',
#  'nonmilitant',
#  'olethreutidae',
#  'panstereorama',
#  'quirky',
#  'outword',
#  'settle',
#  'bruckle',
#  'metaformaldehyde',
#  'metopoceros',
#  'cacostomia',
#  'undercook',
#  'metachrosis',
#  'orthotomic',
#  'uncross',
#  'weesh',
#  'mackereler',
#  'cuckoo',
#  'mappist',
#  'gelandejump',
#  'nonequilateral',
#  'palaetiology',
#  'skedlock',
#  'syllabicness',
#  'kha',
#  'nectandra',
#  'albronze',
#  'pacifist',
#  'wriggler',
#  'pulverize',
#  'presurvey',
#  'consequential',
#  'procuratorial',
#  'loglet',
#  'vitalness',
#  'navarchy',
#  'restainable',
#  'vacillation',
#  'unreactive',
#  'overlip',
#  'transiency',
#  'spirographidin',
#  'escarp',
#  'preincrease',
#  'submarshal',
#  'ecbolic',
#  'trihedron',
#  'neological',
#  'gruffiness',
#  'greffier',
#  'amphiboly',
#  'sprue',
#  'costosuperior',
#  'semicolumn',
#  'unsucked',
#  'aquaemanale',
#  'legit',
#  'psychographic',
#  'dilapidate',
#  'steradian',
#  'metrostenosis',
#  'anesthetic',
#  'englisher',
#  'compressible',
#  'salivant',
#  'schonfelsite',
#  'scirrhosis',
#  'pseudoparalysis',
#  'cercosporella',
#  'interclasp',
#  'unstoppable',
#  'waylayer',
#  'zaque',
#  'harry',
#  'fuchsite',
#  'autotrophic',
#  'windring',
#  'uranometria',
#  'cephalomelus',
#  'downcast',
#  'ginney',
#  'pigyard',
#  'navarrese',
#  'epaxial',
#  'engrailed',
#  'punctiliousness',
#  'damageability',
#  'gossypium',
#  'bowman',
#  'hydrocholecystis',
#  'bepinch',
#  'war',
#  'polymerous',
#  'dividing',
#  'neurophysiology',
#  'grainy',
#  'jocose',
#  'viscometer',
#  'prig',
#  'ventricolumna',
#  'errantia',
#  'supposable',
#  'sex',
#  'sigilative',
#  'four',
#  'reify',
#  'subcaption',
#  'prebasal',
#  'flector',
#  'anguilloid',
#  'microsthene',
#  'barie',
#  'oenanthyl',
#  'unhumid',
#  'zeuglodontidae',
#  'sansei',
#  'calvatia',
#  'securer',
#  'millenary',
#  'unshoeing',
#  'ecclesiastically',
#  'plausibleness',
#  'earthquaked',
#  'ensue',
#  'preceremonial',
#  'supravaginal',
#  'sharepenny',
#  'flagellator',
#  'ethanolamine',
#  'wolve',
#  'coincident',
#  'percept',
#  'overremiss',
#  'otodynia',
#  'undetainable',
#  'akoluthia',
#  'phonetics',
#  'disnature',
#  'molendinar',
#  'gerim',
#  'paracorolla',
#  'mystic',
#  'parapsychological',
#  'possessionist',
#  'unbankably',
#  'mentorism',
#  'refinedness',
#  'beglerbeglic',
#  'alloeostropha',
#  'cryptocarpic',
#  'sulphofication',
#  'shinplaster',
#  'stocking',
#  'befame',
#  'aphnology',
#  'terebinthina',
#  'corybantian',
#  'trigynia',
#  'practitionery',
#  'silphidae',
#  'arikara',
#  'filmic',
#  'matmaker',
#  'gradine',
#  'embus',
#  'leucocytotic',
#  'ebony',
#  'incandescent',
#  'disablement',
#  'abuser',
#  'operatively',
#  'protamine',
#  'unexhibitable',
#  'overmoisten',
#  'caliver',
#  'churr',
#  'diffidentness',
#  'anaerobies',
#  'tripetaloid',
#  'unintercalated',
#  'mishnah',
#  'duodecimally',
#  'interbelligerent',
#  'interruptively',
#  'insular',
#  'peastone',
#  'biurea',
#  'antiministerialist',
#  'melica',
#  'recoction',
#  'santalwood',
#  'sulphogermanate',
#  'apostle',
#  'bucklum',
#  'metasilicate',
#  'neologic',
#  'arthrempyesis',
#  'condurango',
#  'forewing',
#  'prelocate',
#  'unmaltable',
#  'biotomy',
#  'ovovivipara',
#  'tristeza',
#  'unsteep',
#  'endaspidean',
#  'maladventure',
#  'acediamine',
#  'durance',
#  'odontiasis',
#  'ellipsis',
#  'suprapharyngeal',
#  'verticalness',
#  'todea',
#  'brosy',
#  'oscillatorian',
#  'than',
#  'descant',
#  'typhloptosis',
#  'exceptionableness',
#  'expiator',
#  'outspokenness',
#  'succinctory',
#  'looping',
#  'chondromyxosarcoma',
#  'bristlecone',
#  'virtue',
#  'roble',
#  'salesian',
#  'holstein',
#  'gastropore',
#  'physiurgic',
#  'vibratile',
#  'fugitivism',
#  'lamellibranchia',
#  'prizable',
#  'mehmandar',
#  'woodwardia',
#  'sorty',
#  'menagerie',
#  'chloranthaceae',
#  'forconceit',
#  'reincrease',
#  'counterextend',
#  'heptarchic',
#  'prebendary',
#  'preopening',
#  'squadron',
#  'steellike',
#  'peptogenic',
#  'unmaddened',
#  'chirruper',
#  'hyperboloidal',
#  'narcissist',
#  'rakishly',
#  'pandarus',
#  'molter',
#  'chlamydospore',
#  'uncircumlocutory',
#  'dimidiation',
#  'overpopular',
#  'gastrulate',
#  'macrogametocyte',
#  'endothrix',
#  'triodia',
#  'anglophobe',
#  'unhabitableness',
#  'counterreply',
#  'diaglyph',
#  'unignitible',
#  'vat',
#  'fellowlike',
#  'pole',
#  'cathodofluorescence',
#  'overjawed',
#  'thioarseniate',
#  'rapid',
#  'overslide',
#  'doctrinarianism',
#  'gobinism',
#  'moonflower',
#  'muckite',
#  'phrynosoma',
#  'struv',
#  'eyedot',
#  'boundingly',
#  'omitis',
#  'broomer',
#  'atropism',
#  'elution',
#  'untraded',
#  'satinleaf',
#  'unrepliably',
#  'directrices',
#  'nicolo',
#  'nocuously',
#  'cellulate',
#  'euomphalid',
#  'filipinize',
#  'assmannshauser',
#  'madi',
#  'preceding',
#  'scious',
#  'flavescent',
#  'interplait',
#  'kunzite',
#  'bumbledom',
#  'untroublable',
#  'depigmentate',
#  'scrubwood',
#  'alternative',
#  'smutch',
#  'mystifyingly',
#  'pinaleno',
#  'interregna',
#  'paal',
#  'registrarship',
#  'proamniotic',
#  'sporeforming',
#  'interpenetrate',
#  'rompishly',
#  'stenohaline',
#  'froth',
#  'herniation',
#  'synesthesia',
#  'trophosome',
#  'redhibitory',
#  'unitariness',
#  'soldan',
#  'muffin',
#  'triphane',
#  'fictitiously',
#  'semiconic',
#  'befavour',
#  'worshipful',
#  'uncapacious',
#  'sepiolidae',
#  'montane',
#  'rerub',
#  'etiological',
#  'dunghilly',
#  'aleut',
#  'fishskin',
#  'archigaster',
#  'entoptoscopy',
#  'oaken',
#  'senseful',
#  'razzly',
#  'physiogenic',
#  'lingula',
#  'integrally',
#  'sandrock',
#  'latebricole',
#  'desklike',
#  'periclitation',
#  'eparchial',
#  'searchableness',
#  'gabelleman',
#  'grabouche',
#  'proklausis',
#  'enwallow',
#  'skinflintiness',
#  'covertness',
#  'prolificness',
#  'diadochokinetic',
#  'truncated',
#  'coeditorship',
#  'superaccumulation',
#  'bradford',
#  'plenum',
#  'albedo',
#  'substanch',
#  'underdip',
#  'suaharo',
#  'unpiercing',
#  'colorimetry',
#  'mammalogy',
#  'regulated',
#  'hyperapophysis',
#  'tiptoe',
#  'terraba',
#  'vestal',
#  'slut',
#  'pish',
#  'paroxysmally',
#  'pleuracanthus',
#  'unsinewy',
#  'calymma',
#  'alveloz',
#  'describability',
#  'imperatorial',
#  'brissotin',
#  'epinastic',
#  'defalk',
#  'picudo',
#  'packthread',
#  'palaeophysiology',
#  'depressive',
#  'folkmooter',
#  'genitofemoral',
#  'neuroganglion',
#  ...]

# %%
wordunique.sort()

# %%
wordunique[:10]
# Out:
# ['a',
#  'aa',
#  'aal',
#  'aalii',
#  'aam',
#  'aani',
#  'aardvark',
#  'aardwolf',
#  'aaron',
#  'aaronic']

# %%
wordclean = [word.strip().lower() for word in open('word.txt','r')]

# %%
wordclean[:10]
# Out:
# ['a',
#  'a',
#  'aa',
#  'aal',
#  'aalii',
#  'aam',
#  'aani',
#  'aardvark',
#  'aardwolf',
#  'aaron']

# %%
wordclean = sorted(list(set([word.strip().lower() for word in open('word.txt','r')])))

# %%
wordclean[:10]
# Out:
# ['a',
#  'aa',
#  'aal',
#  'aalii',
#  'aam',
#  'aani',
#  'aardvark',
#  'aardwolf',
#  'aaron',
#  'aaronic']

# %%
f = open('word.txt', 'r')
file_str = f.read()

for line in str.split(file_str):
    if len(line) == len(line++): 
        print(line)
# Out:
#   File "<ipython-input-8-ceff8218f4c2>", line 5
#     if len(line) == len(line++):
#                               ^
# SyntaxError: invalid syntax
